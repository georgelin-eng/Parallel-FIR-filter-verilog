# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generates a sin wave input


# Write to text file

# %%
h = [
    0.000000000000000000,
    -0.000394056881421562,
    0.002003032693725564,
    -0.000000000000000003,
    -0.014222568113202589,
    0.029743899259390361,
    -0.000000000000000016,
    -0.112583270357987014,
    0.262160523382816091,
    0.666584880033358362,
    0.262160523382816091,
    -0.112583270357987070,
    -0.000000000000000016,
    0.029743899259390361,
    -0.014222568113202598,
    -0.000000000000000003,
    0.002003032693725566,
    -0.000394056881421562,
    0.000000000000000000,
]

x = range(len(h))

plt.plot(x,h)
plt.show()
